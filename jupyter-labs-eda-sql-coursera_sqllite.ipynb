# %% [markdown]
# ### Connect to the database
#
# Let us first load the SQL extension and establish a connection with the database

# %%
import sqlite3 as sql
import pandas as pd
import numpy as np

# %%
connection1 = sql.connect("/Users/ishanamin/Desktop/Projects/IBMDataScienceCertification/SpaceY/SpaceX.db")

# %% [markdown]
# ## Tasks
#
# Now write and execute SQL queries to solve the assignment tasks.
#
# **Note: If the column names are in mixed case enclose it in double quotes
# For Example "Landing_Outcome"**
#
# ### Task 1
#
# ##### Display the names of the unique launch sites  in the space mission

# %%
sql_query = '''SELECT DISTINCT(Launch_Site) FROM Spacex'''
df = pd.read_sql_query(sql_query, connection1)
df
# Out:
#     Launch_Site
# 0   CCAFS LC-40
# 1   VAFB SLC-4E
# 2    KSC LC-39A
# 3  CCAFS SLC-40

# %% [markdown]
# ### Task 2
#
# ##### Display 5 records where launch sites begin with the string 'CCA'

# %%
sql_query = '''SELECT * FROM Spacex WHERE Launch_Site LIKE 'CCA%' LIMIT 5'''
df = pd.read_sql_query(sql_query, connection1)
df
# Out:
#          Date Time (UTC) Booster_Version  Launch_Site  \
# 0  04-06-2010   18:45:00  F9 v1.0  B0003  CCAFS LC-40
# 1  08-12-2010   15:43:00  F9 v1.0  B0004  CCAFS LC-40
# 2  22-05-2012   07:44:00  F9 v1.0  B0005  CCAFS LC-40
# 3  08-10-2012   00:35:00  F9 v1.0  B0006  CCAFS LC-40
# 4  01-03-2013   15:10:00  F9 v1.0  B0007  CCAFS LC-40
#
#                                              Payload  PAYLOAD_MASS__KG_  \
# 0               Dragon Spacecraft Qualification Unit                  0
# 1  Dragon demo flight C1, two CubeSats, barrel of...                  0
# 2                              Dragon demo flight C2                525
# 3                                       SpaceX CRS-1                500
# 4                                       SpaceX CRS-2                677
#
#        Orbit         Customer Mission_Outcome     Landing _Outcome
# 0        LEO           SpaceX         Success  Failure (parachute)
# 1  LEO (ISS)  NASA (COTS) NRO         Success  Failure (parachute)
# ...

# %% [markdown]
# ### Task 3
#
# ##### Display the total payload mass carried by boosters launched by NASA (CRS)

# %%
sql_query = '''SELECT SUM(Payload_Mass) AS 'Total Payload Mass' FROM Spacex WHERE Customer = "NASA (CRS)"'''
df = pd.read_sql_query(sql_query, connection1)
df
# Out:
#    Total Payload Mass
# 0               45596

# %% [markdown]
# ### Task 4
#
# ##### Display average payload mass carried by booster version F9 v1.1

# %%
sql_query = '''SELECT AVG(Payload_Mass) AS 'Average Payload Mass by F9 v1.1' FROM Spacex WHERE Booster_Version = "F9 v1.1"'''
df = pd.read_sql_query(sql_query, connection1)
df
# Out:
#    Average Payload Mass by F9 v1.1
# 0                           2928.4

# %% [markdown]
# ### Task 5
#
# ##### List the date when the first succesful landing outcome in ground pad was acheived.
#
# *Hint:Use min function*

# %%
sql_query = '''SELECT MIN(Date) FROM Spacex WHERE Landing_Outcome = "Success (ground pad)"'''
df = pd.read_sql_query(sql_query, connection1)
df
# Out:
#     MIN(Date)
# 0  2015-12-22

# %% [markdown]
# ### Task 6
#
# ##### List the names of the boosters which have success in drone ship and have payload mass greater than 4000 but less than 6000

# %%
sql_query = '''SELECT DISTINCT(Booster_Version) FROM Spacex WHERE Landing_Outcome = "Success (drone ship)" AND Payload_Mass > 4000 AND Payload_Mass < 6000'''
df = pd.read_sql_query(sql_query, connection1)
df
# Out:
#   Booster_Version
# 0     F9 FT B1022
# 1     F9 FT B1026
# 2  F9 FT  B1021.2
# 3  F9 FT  B1031.2

# %% [markdown]
# ### Task 7
#
# ##### List the total number of successful and failure mission outcomes

# %%
sql_query = '''SELECT COUNT(Mission_Outcome) FROM Spacex WHERE Mission_Outcome LIKE "Success%"'''
df = pd.read_sql_query(sql_query, connection1)
df
# Out:
#    COUNT(Mission_Outcome)
# 0                     100

# %%
sql_query2 = '''SELECT COUNT(Mission_Outcome) FROM Spacex WHERE Mission_Outcome LIKE "Failure%"'''
df2 = pd.read_sql_query(sql_query2, connection1)
df2
# Out:
#    COUNT(Mission_Outcome)
# 0                       1

# %% [markdown]
# ### Task 8
#
# ##### List the   names of the booster_versions which have carried the maximum payload mass. Use a subquery

# %%
sql_query = '''SELECT DISTINCT(Booster_Version) FROM Spacex WHERE Payload_Mass = (SELECT MAX(Payload_Mass) FROM Spacex)'''
df = pd.read_sql_query(sql_query, connection1)
df
# Out:
#    Booster_Version
# 0    F9 B5 B1048.4
# 1    F9 B5 B1049.4
# 2    F9 B5 B1051.3
# 3    F9 B5 B1056.4
# 4    F9 B5 B1048.5
# 5    F9 B5 B1051.4
# 6    F9 B5 B1049.5
# 7   F9 B5 B1060.2
# 8   F9 B5 B1058.3
# 9    F9 B5 B1051.6
# 10   F9 B5 B1060.3
# 11  F9 B5 B1049.7

# %% [markdown]
# ### Task 9
#
# ##### List the records which will display the month names, failure landing_outcomes in drone ship ,booster versions, launch_site for the months in year 2015.
#
# **Note: SQLLite does not support monthnames. So you need to use  substr(Date, 4, 2) as month to get the months and substr(Date,7,4)='2015' for year.**

# %%
sql_query = '''SELECT substr(Date,6,2), Landing_Outcome, Booster_Version, Launch_Site FROM Spacex WHERE substr(Date,1,4) = '2015' AND Landing_Outcome = "Failure (drone ship)"'''
df = pd.read_sql_query(sql_query, connection1)
df
# Out:
#   substr(Date,6,2)       Landing_Outcome Booster_Version  Launch_Site
# 0               01  Failure (drone ship)   F9 v1.1 B1012  CCAFS LC-40
# 1               04  Failure (drone ship)   F9 v1.1 B1015  CCAFS LC-40

# %% [markdown]
# ### Task 10
#
# ##### Rank the  count of  successful landing_outcomes between the date 04-06-2010 and 20-03-2017 in descending order.

# %%
sql_query = '''SELECT Landing_Outcome, COUNT(Landing_Outcome) FROM Spacex WHERE Date BETWEEN '2010-06-04' AND '2017-03-20' GROUP BY Landing_Outcome ORDER BY COUNT(Landing_Outcome) DESC'''
df = pd.read_sql_query(sql_query, connection1)
df
# Out:
#           Landing_Outcome  COUNT(Landing_Outcome)
# 0              No attempt                      10
# 1    Success (drone ship)                       5
# 2    Failure (drone ship)                       5
# 3    Success (ground pad)                       3
# 4      Controlled (ocean)                       3
# 5    Uncontrolled (ocean)                       2
# 6     Failure (parachute)                       2
# 7  Precluded (drone ship)                       1
